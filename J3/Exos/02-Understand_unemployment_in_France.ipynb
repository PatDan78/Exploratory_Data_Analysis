# %% [markdown]
# # Understanding unemployment in France
#
# Have you ever wondered where the numbers came from when politicians or the media talk about unemployment ? Being a subject of interest in Western countries, let's try to understand what is happening in terms of unemployment in France. For this, we have retrieved data from [data.gouv](https://www.insee.fr/fr/statistiques/3555153#consulter).
# They represent unemployment data in France in 2017.

# %% [markdown]
# ## Description of the dataset
#
# Have a look at the description of the dataset [here](https://www.insee.fr/fr/statistiques/3555153#documentation)

# %% [markdown]
# * Import useful libraries
#   * pandas
#   * numpy
#   * matplotlib

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load the data from fdeec17.csv

# %%
dataset = pd.read_csv("fdeec17.csv")

# %% [markdown]
# * By doing a [pie-chart](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.pie.html), show the share of unemployed, inactive and employed persons in France (from the variable ACTEU). Make sure the following information is displayed :
#
#   * The percentage of each category
#   * A legend

# %%
dataset.head()
# Out:
#    Unnamed: 0  ANNEE  TRIM  CATAU2010R  METRODOM  TYPMEN7  AGE3  AGE5  COURED  \
# 0           0   2017     1           1         1        2    50    50       2
# 1           1   2017     1           1         1        2    15    15       2
# 2           2   2017     1           1         1        2    15    15       2
# 3           3   2017     3           1         1        2    50    50       2
# 4           4   2017     3           1         1        2    15    15       2
#
#    ENFRED  ...  DIP11  CSTOTPRM  IDENTM     EXTRIAN  EMPNBH  HREC  HHCE  \
# 0       1  ...   30.0      52.0       1  263.388752    37.0   NaN  37.0
# 1       2  ...   42.0      52.0       1  263.388752    32.0   NaN  32.0
# 2       2  ...   31.0      52.0       1  263.388752    38.0   NaN  38.0
# 3       1  ...   30.0      52.0       2  176.893923    37.0   NaN  37.0
# 4       2  ...   42.0      52.0       2  176.893923    40.0   NaN  32.0
#
#    HPLUSA  JOURTR  NBTOTE
# 0     NaN     5.0     NaN
# 1     NaN     4.0     NaN
# 2     NaN     5.0     NaN
# 3     NaN     5.0     NaN
# 4     NaN     4.0     NaN
#
# [5 rows x 126 columns]

# %%
# Récupère tout les noms des colonnes

dataset.columns.values
# Out:
# array(['Unnamed: 0', 'ANNEE', 'TRIM', 'CATAU2010R', 'METRODOM', 'TYPMEN7',
#        'AGE3', 'AGE5', 'COURED', 'ENFRED', 'NFRRED', 'SEXE', 'ACTEU',
#        'ACTEU6', 'ACTIF', 'ACTOP', 'AIDFAM', 'ANCCHOM', 'ANCINACT',
#        'CONTACT', 'CREACCP', 'DEM', 'DISPOC', 'GARDEB', 'HALOR',
#        'INSCONT', 'MRA', 'MRB', 'MRBBIS', 'MRC', 'MRD', 'MRDBIS', 'MRE',
#        'MREC', 'MRF', 'MRG', 'MRGBIS', 'MRH', 'MRI', 'MRJ', 'MRK', 'MRL',
#        'MRM', 'MRN', 'MRO', 'MRPASSA', 'MRPASSB', 'MRPASSC', 'MRS',
#        'NONDIC', 'NREC', 'NRECA', 'NRECB', 'OCCREF', 'OFFICC', 'OFFRE',
#        'PASTRA', 'PASTRB', 'PASTRF', 'PERCREV', 'RABS', 'RAISNREC',
#        'RAISNSOU', 'RAISPAS', 'SOU', 'SOUA', 'SOUB', 'SOUC', 'SOUSEMPL',
#        'STCHE', 'TEMP', 'TRAREF', 'TYPCONT', 'TYPCONTB', 'CHPUB', 'CSE',
#        'CSER', 'CSP', 'CSTOT', 'CSTOTR', 'FONCTC', 'NAFG004UN',
#        'NAFG010UN', 'NAFG017UN', 'NAFG021UN', 'NAFG038UN', 'NAFG088UN',
#        'PUB3FP', 'QPRC', 'STC', 'CONTRA', 'RDET', 'STAT2', 'STATOEP',
#        'STATUT', 'STATUTR', 'TITC', 'CSTMN', 'CSTPLC', 'DISPPLC', 'DUHAB',
#        'GARDEA', 'HHC6', 'HORAIC', 'RAISON', 'RAISTP', 'STMN', 'STPLC',
#        'TPPRED', 'TXTPPRED', 'ANCENTR4', 'SITANT', 'AAC', 'CSA', 'NAFANT',
#        'NAFANTG004', 'DIP11', 'CSTOTPRM', 'IDENTM', 'EXTRIAN', 'EMPNBH',
#        'HREC', 'HHCE', 'HPLUSA', 'JOURTR', 'NBTOTE'], dtype=object)

# %%
dataset.info
# Out:
# <bound method DataFrame.info of         Unnamed: 0  ANNEE  TRIM  CATAU2010R  METRODOM  TYPMEN7  AGE3  AGE5  \
# 0                0   2017     1           1         1        2    50    50
# 1                1   2017     1           1         1        2    15    15
# 2                2   2017     1           1         1        2    15    15
# 3                3   2017     3           1         1        2    50    50
# 4                4   2017     3           1         1        2    15    15
# ...            ...    ...   ...         ...       ...      ...   ...   ...
# 428637      428637   2017     2           1         2        3    50    50
# 428638      428638   2017     3           1         2        3    50    60
# 428639      428639   2017     3           1         2        3    50    50
# 428640      428640   2017     4           1         2        3    50    60
# 428641      428641   2017     4           1         2        3    50    50
#
#         COURED  ENFRED  ...  DIP11  CSTOTPRM  IDENTM     EXTRIAN  EMPNBH  \
# 0            2       1  ...   30.0      52.0       1  263.388752    37.0
# 1            2       2  ...   42.0      52.0       1  263.388752    32.0
# 2            2       2  ...   31.0      52.0       1  263.388752    38.0
# 3            2       1  ...   30.0      52.0       2  176.893923    37.0
# 4            2       2  ...   42.0      52.0       2  176.893923    40.0
# ...        ...     ...  ...    ...       ...     ...         ...     ...
# 428637       1       2  ...   71.0      75.0  234080   27.451625     0.0
# 428638       1       2  ...   33.0      75.0  234081   24.287870     NaN
# 428639       1       2  ...   71.0      75.0  234081   24.287870     NaN
# 428640       1       2  ...   33.0      75.0  234082   19.596248     NaN
# 428641       1       2  ...   71.0      75.0  234082   19.596248     NaN
#
#         HREC  HHCE  HPLUSA  JOURTR  NBTOTE
# 0        NaN  37.0     NaN     5.0     NaN
# 1        NaN  32.0     NaN     4.0     NaN
# 2        NaN  38.0     NaN     5.0     NaN
# 3        NaN  37.0     NaN     5.0     NaN
# 4        NaN  32.0     NaN     4.0     NaN
# ...      ...   ...     ...     ...     ...
# 428637   NaN   NaN     NaN     NaN     NaN
# 428638   NaN   NaN     NaN     NaN     NaN
# 428639   NaN   NaN     NaN     NaN     NaN
# 428640   NaN   NaN     NaN     NaN     NaN
# 428641   NaN   NaN     NaN     NaN     NaN
#
# [428642 rows x 126 columns]>

# %%
dataset['ACTEU']
# Out:
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#          ...
# 428637    3.0
# 428638    3.0
# 428639    3.0
# 428640    3.0
# 428641    3.0
# Name: ACTEU, Length: 428642, dtype: float64

# %%
# voir les valeurs uniques dans ACTEU
# J'ai quoi dans ma variable ACTEU

dataset['ACTEU'].unique()
# Out:
# array([ 1.,  3.,  2., nan])

# %%
# Compter les valeurs uniques dans ACTEU

dataset['ACTEU'].value_counts()
# Out:
# ACTEU
# 3.0    207520
# 1.0    198054
# 2.0     21864
# Name: count, dtype: int64

# %%
# Attribue un nom à une valeur

chomeurs = dataset['ACTEU'].apply(lambda x:
                                "Actif Occupé" if x == 1
                                 else "Inactif" if x == 3
                                 else "Chomeur" if x == 2
                                 else "NAN")

# %%
# Compte le nombre d'ocurence par nom
# Attention nous avons des Str et des Int

chomeurs.value_counts()
# Out:
# ACTEU
# Inactif         207520
# Actif Occupé    198054
# Chomeur          21864
# NAN               1204
# Name: count, dtype: int64

# %%
# Compter les occurrences de chaque catégories
# Repasse en int pour pouvoir faire le pie_chart

comptage_chomeurs = chomeurs.value_counts()

# %%
comptage_chomeurs
# Out:
# ACTEU
# Inactif         207520
# Actif Occupé    198054
# Chomeur          21864
# NAN               1204
# Name: count, dtype: int64

# %%
# Créer un pie_chart

plt.pie(comptage_chomeurs,
        labels= comptage_chomeurs.index,
        explode= (0.1, 0.1, 0.4, 0.2),
        autopct= '%1.1f%%',
        shadow= True,
        startangle= 90, )

# Afficher la légende sur le meilleur emplacement disponible
plt.legend(comptage_chomeurs.index, loc='upper right', bbox_to_anchor=(1.5, 1))

plt.show()

# %% [markdown]
# ---> The unemployment figure seems low and, if we look at the explanation of the *inactive*, it seems to include a lot of people (students, people not looking for work, etc.).

# %% [markdown]
# * Make the same graph on the variable ACTEU6 which is more precise on the type of actives.

# %% [markdown]
#  Le chiffre du chômage semble faible et, si l'on regarde l'explication des inactifs , il semble inclure beaucoup de monde (étudiants, personnes ne cherchant pas de travail, etc.).

# %% [markdown]
# Faites le même graphique sur la variable ACTEU6 qui est plus précis sur le type d'actifs.

# %%
dataset['ACTEU6'].value_counts()
# Out:
# ACTEU6
# 1.0    198054
# 6.0    172921
# 5.0     34599
# 3.0     20854
# 4.0      1010
# Name: count, dtype: int64

# %%
chomeurs_id = dataset['ACTEU6'].apply(lambda x:
                                "Actif Occupé" if x == 1
                                else "Chomeurs PSERE" if x == 3
                                else "Autre chomeur BIT" if x ==  4
                                else "Etudiant, élève, statgiaire..." if x == 5
                                else "Autres Inactifs" if x == 6 else "NAN")

# %%
chomeurs_id.value_counts()
# Out:
# ACTEU6
# Actif Occupé                      198054
# Autres Inactifs                   172921
# Etudiant, élève, statgiaire...     34599
# Chomeurs PSERE                     20854
# NAN                                 1204
# Autre chomeur BIT                   1010
# Name: count, dtype: int64

# %%
pie_chart_data = chomeurs_id.value_counts()

# %%
pie_chart_data
# Out:
# ACTEU6
# Actif Occupé                      198054
# Autres Inactifs                   172921
# Etudiant, élève, statgiaire...     34599
# Chomeurs PSERE                     20854
# NAN                                 1204
# Autre chomeur BIT                   1010
# Name: count, dtype: int64

# %%
plt.figure(figsize = (10,5))

plt.pie(
    pie_chart_data,
    autopct = '%1.1f%%',
    shadow = True,
    startangle = 90,
    explode = (0.1, 0.1,0.3,0.6,0.8, 1.3),
    radius = 1.5
       )

plt.legend(pie_chart_data.index, bbox_to_anchor=(1.1, 1.05))
plt.show()

# %% [markdown]
# * By ploting a [stacked bar chart](https://pythonmatplotlibtips.blogspot.com/2018/11/normalized-stacked-barplot-number-percentage-python-matplotlib.html), compare :
#
#   * The ratio *chômeurs* / *Actifs occupés*
#   * The ratio *chômeurs* / *Actifs occupés + Inactifs*

# %% [markdown]
# En traçant un graphique à barres empilées , comparez :
#
# * The ratio chômeurs / Actifs occupés
# * The ratio chômeurs / Actifs occupés + Inactifs

# %%
# On recréé les données dont on a besoin
chomeurs = dataset['ACTEU'].apply(lambda x:
                               "Actif Occupé" if x==1
                               else "Chômeur" if x == 2
                               else "Inactif" if x==3
                               else "NAN")

# %%
chart_data = chomeurs.value_counts()
chart_data
# Out:
# ACTEU
# Inactif         207520
# Actif Occupé    198054
# Chômeur          21864
# NAN               1204
# Name: count, dtype: int64

# %%
# The ratio chômeurs / Actifs occupés

ratio_1 = chart_data["Chômeur"] / chart_data["Actif Occupé"]
rat_1 = ratio_1.round(2)

print(f"ration chômeurs / actifs occupés : {rat_1}.")
# Out:
# ration chômeurs / actifs occupés : 0.11.

# %%
# The ratio chômeurs / Actifs occupés + Inactifs

ratio_2 = chart_data["Chômeur"] / (chart_data["Actif Occupé"] + chart_data["Inactif"])
rat_2 = ratio_2.round(2)

print(f"ration chômeurs / (actifs occupés + Inactifs) : {rat_2}")
# Out:
# ration chômeurs / (actifs occupés + Inactifs) : 0.05

# %%
# création d'une liste de valeurs

data = [rat_1, rat_2]
data
# Out:
# [0.11, 0.05]

# %%
# np.array([1,1]) - pour créer un tableau avec 1 liste de 2 éléments de 100% 

data_actifs = np.array([1,1]) - data
print(f"Rapports d'actifs\n {data_actifs}")
# Out:
# Rapports d'actifs
#  [0.89 0.95]

# %%
legend = ["Chômeurs / Actifs Occupés", "Chômeurs / Actifs + Inactifs"]
legend
# Out:
# ['Chômeurs / Actifs Occupés', 'Chômeurs / Actifs + Inactifs']

# %%
# Create two bar charts who will be surperposed
## Don't forget to use two ax.bar()
## To create legends, we can use ax1.text()
## To create a title, we can yse ax1.set_title()

plt.figure()

plt.bar(legend,
         data,
        label="Chômeurs")

plt.bar(legend,
        data_actifs,
        bottom=data,
        label="Non-Chômeurs")

plt.text(legend[0], 0.6, np.round(data_actifs[0],2), ha = "center", va = "center")
plt.text(legend[0], 0.05, np.round(data[0],2), ha = "center", va = "center")

plt.text(legend[1], 0.6, np.round(data_actifs[1],2), ha = "center", va = "center")
plt.text(legend[1], 0.025, np.round(data[1],2), ha = "center", va = "center")

plt.legend()
plt.title("Répartition des chômeurs par rapport à la population active & la population totale")

plt.show()

# %% [markdown]
# It seems that we were 11% unemployed among the active (working) population in France in 2017 according to the ILO.

# %% [markdown]
# * By creating a [*bar chart*](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.bar.html) again, this time look at the distribution of unemployment seniority. The name of the variable is ANCCHOM

# %% [markdown]
# Il semblerait que nous étions 11% de chômeurs parmi la population active en France en 2017 selon l'OIT.

# %% [markdown]
# * En créant à nouveau un graphique à barres , examinez cette fois la répartition de l'ancienneté au chômage. Le nom de la variable est ANCCHOM

# %%
dataset["ANCCHOM"].value_counts()
# Out:
# ANCCHOM
# 8.0    3906
# 4.0    3648
# 5.0    3398
# 2.0    3270
# 3.0    3193
# 7.0    2289
# 6.0    1132
# 1.0     902
# Name: count, dtype: int64

# %%
# On recréé les données dont on a besoin
duree_chomage = dataset['ANCCHOM'].apply(lambda x:
                               "Moins d'un mois" if x==1
                               else "De 1 mois à moins de 3 mois" if x == 2
                               else "De 3 mois à moins de 6 mois" if x == 3
                               else "De 6 mois à moins de un an" if x == 4
                               else "De 1 an à moins de 1 an et demi" if x == 5
                               else "De 1 an et demi à moins de 2 ans" if x == 6
                               else "De 2 an à moins de 3 ans" if x == 7
                               else "De 3 ans et plus" if x == 8
                               else "NAN")

# %%
duree_chomage.value_counts()
# Out:
# ANCCHOM
# NAN                                 406904
# De 3 ans et plus                      3906
# De 6 mois à moins de un an            3648
# De 1 an à moins de 1 an et demi       3398
# De 1 mois à moins de 3 mois           3270
# De 3 mois à moins de 6 mois           3193
# De 2 an à moins de 3 ans              2289
# De 1 an et demi à moins de 2 ans      1132
# Moins d'un mois                        902
# Name: count, dtype: int64

# %%
chart_data = duree_chomage.value_counts()

# %%
chart_data
# Out:
# ANCCHOM
# NAN                                 406904
# De 3 ans et plus                      3906
# De 6 mois à moins de un an            3648
# De 1 an à moins de 1 an et demi       3398
# De 1 mois à moins de 3 mois           3270
# De 3 mois à moins de 6 mois           3193
# De 2 an à moins de 3 ans              2289
# De 1 an et demi à moins de 2 ans      1132
# Moins d'un mois                        902
# Name: count, dtype: int64

# %%
plt.figure(figsize=(25,5))
plt.bar(chart_data.index[1:], chart_data.values[1:])
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# * The distribution doesn't look good on the bar chart, try doing it again on a piechart.

# %%
plt.figure(figsize = (10,5))

plt.pie(
    chart_data[1:],
    autopct = '%1.1f%%',
    shadow = True,
    startangle = 90,
    radius = 1.5)

plt.legend(pie_chart_data.index, bbox_to_anchor=(1.1, 1.05))
plt.show()

# %% [markdown]
# * It would be interesting to see the distribution of people registered with Pôle Emploi or an employment agency among these unemployed people. Look at this distribution thanks to the CONTACT column
#   * Directly remove the NaN from your chart

# %% [markdown]
# Il serait intéressant de voir la répartition des personnes inscrites à Pôle Emploi ou à une agence pour l'emploi parmi ces chômeurs. Regardez cette répartition grâce à la colonne CONTACT

# %% [markdown]
# * Supprimez directement le NaN de votre graphique

# %%
dataset["CONTACT"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 428637   NaN
# 428638   NaN
# 428639   NaN
# 428640   NaN
# 428641   NaN
# Name: CONTACT, Length: 428642, dtype: float64>

# %%
# Suppression des valeurs NAN dans la colonne CONTACT

dataset_sans_nan = dataset.dropna(subset=['CONTACT'])

# %%
dataset_sans_nan["CONTACT"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 15        1.0
# 17        1.0
# 93        1.0
# 97        1.0
# 99        1.0
#          ...
# 428624    1.0
# 428625    1.0
# 428629    1.0
# 428631    2.0
# 428633    2.0
# Name: CONTACT, Length: 29128, dtype: float64>

# %%
contact = dataset['CONTACT'].apply(lambda x:
                                       "Oui" if x == 1
                                       else "Non" if x == 2
                                       else "NAN")

chart_data = contact.value_counts()
chart_data
# Out:
# CONTACT
# NAN    399514
# Non     15984
# Oui     13144
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,5)) # initialise une feuille

plt.bar(chart_data[1:].index, chart_data[1:].values)
plt.title("Inscription dans un organisme de placement")
plt.show()

# %% [markdown]
# * Regardons ce qui pousse les français à changer d'emploi, grâce à la colonne CREACCP, crééz un bar chart horizontale qui va permettre de connaitre les principales raisons de changement d'emploi des français.

# %%
dataset["CREACCP"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 428637   NaN
# 428638   NaN
# 428639   NaN
# 428640   NaN
# 428641   NaN
# Name: CREACCP, Length: 428642, dtype: float64>

# %%
creaccp = dataset['CREACCP'].apply(lambda x:

                                "Risque de perdre ou va perdre son emploi actuel (y compris fin de contrats courts)" if x == 1
                                else "Désire un emploi plus intéressant" if x == 2
                                else "Veut un emploi plus stable (CDI)" if x == 3
                                else "Veut travailler plus d'heures" if x == 4
                                else "Désire un travail avec un rythme horaire plus adapté ou plus modulable" if x == 5
                                else "Désire des conditions de travail moins pénibles ou plus adaptées à sa santé" if x == 6
                                else "Désire augmenter ses revenus" if x == 7
                                else "Désire diminuer son temps de transport" if x == 8
                                else "Doit ou veut déménager" if x == 9
                                else "Veut s'installer à son compte" if x == 10
                                else "Veut changer de métier ou de secteur" if x == 11
                                else "Trouve l'ambiance de travail mauvaise, les relations de travail conflictuelles" if x == 12
                                else "NAN")

chart_data = creaccp.value_counts(ascending=True)
chart_data
# Out:
# CREACCP
# Doit ou veut déménager                                                                   216
# Veut s'installer à son compte                                                            354
# Désire diminuer son temps de transport                                                   598
# Désire un travail avec un rythme horaire plus adapté ou plus modulable                  1102
# Trouve l'ambiance de travail mauvaise, les relations de travail conflictuelles          1223
# Veut changer de métier ou de secteur                                                    1392
# Veut travailler plus d'heures                                                           1404
# Risque de perdre ou va perdre son emploi actuel (y compris fin de contrats courts)      1582
# Désire des conditions de travail moins pénibles ou plus adaptées à sa santé             1820
# Veut un emploi plus stable (CDI)                                                        2462
# Désire un emploi plus intéressant                                                       2779
# Désire augmenter ses revenus                                                            6775
# NAN                                                                                   406935
# Name: count, dtype: int64

# %%
s = np.sum(chart_data.values[:-1])
print(s)
# Out:
# 21707

# %%
repartition = [np.round(element/s*100,2) for element in chart_data.values[:-1]]
repartition
# Out:
# [1.0, 1.63, 2.75, 5.08, 5.63, 6.41, 6.47, 7.29, 8.38, 11.34, 12.8, 31.21]

# %%
# plt.figure(figsize=(20,10))
plt.title("classement des raisons pour lesquelles les français veulent changer de job")
plt.barh(chart_data.index[:-1], repartition, color='skyblue')
plt.xlabel("Répartition en Pourcentage")


for i in range(len(repartition)):
    plt.text(repartition[i], chart_data.index[:-1][i],'{}%'.format(repartition[i]))

plt.show()

# %% [markdown]
# * Let's end this exercise by looking at the distribution of desired hours for those looking for part-time work. To do this, use the HREC column.
#
#   * First try to simply create a histogram without the density function.
#   * To create the density function, you will need to use the following formula:
#       ```y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))```
#
#      where *mu* is the mean of the distribution and *sigma* is the standard deviation.  You can help yourself with this tutorial [histogram with Density](https://matplotlib.org/3.1.1/gallery/statistics/histogram_features.html)

# %%
num_bins=len(dataset['HREC'].value_counts())

# %%
mu = dataset['HREC'].mean()  # mean of distribution
sigma = dataset['HREC'].std()  # standard deviation of distribution

plt.figure()

# the histogram of the data
n, bins, patches = plt.hist(dataset['HREC'], 20, density=True)

# Formule pour la densité
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))

plt.plot(bins, y, '--')
plt.xlabel('Smarts')
plt.ylabel('Probability density')
plt.title(r'Histogram : $\mu={}$, $\sigma={}$'.format(np.round(mu,2), np.round(sigma,2)))
plt.show()
